# %% [markdown]
# # **데이터** **준비**

# %%
# Install the font (malgun.ttf for Malgun Gothic)
import matplotlib.font_manager as fm
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# Set font configuration for Korean text
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'  # Adjust the path based on your font
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)

# %%
# 관련 라이브러리 불러오기
import pandas as pd           #판다스
import matplotlib as mpl       #맷플롭립
import matplotlib.pylab as plt   #맷플롭립
import seaborn as sns          #시본
import numpy as np           #넘파이
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc




# GitHub raw 버전의 URL을 사용
url = "https://raw.githubusercontent.com/djewopitw/work/main/%EA%B5%AD%EC%84%B8%EC%B2%AD_%EC%8B%AC%EC%82%AC%EC%B2%AD%EA%B5%AC%20%EC%B2%98%EB%A6%AC%20%ED%98%84%ED%99%A9_%EB%82%A9%EC%84%B8%EC%9E%90%EC%9C%A0%ED%98%95_20221231.csv"

# URL로부터 데이터를 읽어옴
df_tax = pd.read_csv(url, encoding='euc-kr')

# 데이터프레임 정보 출력
df_tax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   구분1      21 non-null     object
#  1   구분2      21 non-null     object
#  2   전년이월 건수  21 non-null     int64
#  3   당년접수 건수  21 non-null     int64
#  4   각하 건수    21 non-null     int64
#  5   기각 건수    21 non-null     int64
#  6   인용 건수    21 non-null     int64
#  7   인용률      21 non-null     float64
#  8   처리세액     21 non-null     int64
#  9   감세액      21 non-null     int64
#  10  감세액 비율   21 non-null     float64
#  11  이월건수     21 non-null     int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 2.1+ KB

# %%
# 수정된 raw 버전의 URL을 사용
url2 = "https://raw.githubusercontent.com/djewopitw/work/main/%EA%B5%AD%EC%84%B8%EC%B2%AD_%EA%B3%A0%EC%95%A1%EC%83%81%EC%8A%B5%EC%B2%B4%EB%82%A9%EC%9E%90%20%EB%AA%85%EB%8B%A8%EA%B3%B5%EA%B0%9C%EC%9E%90%EC%9D%98%20%ED%98%84%EA%B8%88%EC%A7%95%EC%88%98%EC%8B%A4%EC%A0%81_20221231.csv"

# URL로부터 데이터를 읽어옴
df_no_taxes = pd.read_csv(url2, encoding='euc-kr')

# 데이터프레임 정보 출력
df_no_taxes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   구분             7 non-null      object
#  1   당해연도 인원        7 non-null      int64
#  2   당해연도 납부세액(억원)  7 non-null      int64
#  3   누계 인원          7 non-null      int64
#  4   누계 납부세액(억원)    7 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 408.0+ bytes

# %%
url3 = "https://github.com/djewopitw/work/raw/main/%EA%B5%AD%EC%84%B8%EC%B2%AD_%EA%B3%A0%EC%95%A1%EC%83%81%EC%8A%B5%EC%B2%B4%EB%82%A9%EC%9E%90%20%EB%AA%85%EB%8B%A8%EA%B3%B5%EA%B0%9C%20%EC%8B%A4%EC%A0%81_20211231.csv"

# URL로부터 데이터를 읽어옴
df_no_taxes1 = pd.read_csv(url3, encoding='euc-kr')

# 데이터프레임 정보 출력
df_no_taxes1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   구분1              29 non-null     object
#  1   구분2              29 non-null     object
#  2   신규공개자 인원         29 non-null     int64
#  3   신규공개자 체납세액 (억원)  29 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
df_tax
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# ...

# %%
df_no_taxes
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 0  서울청     1459           1054  12696        10800
# 1  중부청     1300            766  11441         7100
# 2  인천청      867            362   3456         1363
# 3  대전청      565            213   3511         1373
# 4  광주청      334            204   2134         1418
# 5  대구청      320            109   2055         1056
# 6  부산청      742            347   4730         2806

# %%
df_no_taxes1
# Out:
#         구분1        구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 0       지역별         서울      1274            11274
# 1       지역별         인천       492             4160
# 2       지역별         경기      2326            16416
# 3       지역별         강원       125              762
# 4       지역별         대전       149              918
# 5       지역별         충북       166              932
# 6       지역별         충남       311             1778
# 7       지역별         세종        38              223
# 8       지역별         광주       159             1354
# 9       지역별         전북       176             1011
# 10      지역별         전남       174             1361
# 11      지역별         대구       214             1186
# 12      지역별         경북       280             3491
# 13      지역별         부산       376             4203
# 14      지역별         울산       167              980
# 15      지역별         경남       429             2461
# 16      지역별         제주       160             1102
# 17  체납액 규모별      2억 이상      4734            16100
# ...

# %%
df_tax_copy_backup = df_tax.copy()
df_tax_copy_backup
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# ...

# %%
df_tax_copy_backup1 = df_tax.copy()
df_tax_copy_backup1
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# ...

# %%
df_no_taxes_copy_backup = df_no_taxes.copy()
df_no_taxes_copy_backup
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 0  서울청     1459           1054  12696        10800
# 1  중부청     1300            766  11441         7100
# 2  인천청      867            362   3456         1363
# 3  대전청      565            213   3511         1373
# 4  광주청      334            204   2134         1418
# 5  대구청      320            109   2055         1056
# 6  부산청      742            347   4730         2806

# %% [markdown]
# # **데이터 보기**

# %%
df_tax.describe() #데이터프레임의 기초 통계 확인
# Out:
#          전년이월 건수     당년접수 건수      각하 건수       기각 건수      인용 건수        인용률  \
# count  21.000000   21.000000  21.000000   21.000000  21.000000  21.000000
# mean   12.285714   46.571429   4.952381   32.857143   7.904762  19.080952
# std    12.911789   41.592753   6.800560   31.219042   7.654442  11.003346
# min     0.000000    1.000000   0.000000    2.000000   0.000000   0.000000
# 25%     4.000000   11.000000   1.000000   11.000000   2.000000  11.200000
# 50%     6.000000   30.000000   2.000000   20.000000   4.000000  16.700000
# 75%    20.000000   74.000000   6.000000   52.000000  12.000000  25.200000
# max    44.000000  131.000000  24.000000  107.000000  27.000000  50.000000
#
#                처리세액          감세액     감세액 비율       이월건수
# count     21.000000    21.000000  21.000000  21.000000
# mean    5927.047619   834.666667  13.095238  13.142857
# std     7029.854362  1247.665193   8.112181  11.363475
# min       56.000000     0.000000   0.000000   1.000000
# ...

# %%
df_tax.dtypes # 데이터유형 확인
# Out:
# 구분1         object
# 구분2         object
# 전년이월 건수      int64
# 당년접수 건수      int64
# 각하 건수        int64
# 기각 건수        int64
# 인용 건수        int64
# 인용률        float64
# 처리세액         int64
# 감세액          int64
# 감세액 비율     float64
# 이월건수         int64
# dtype: object

# %%
df_tax.loc[0] # 데이터 행 인덱스 확인
# Out:
# 구분1        청구세액 규모별
# 구분2          1천만 미만
# 전년이월 건수          44
# 당년접수 건수         131
# 각하 건수            24
# 기각 건수           107
# 인용 건수            16
# 인용률            10.9
# 처리세액            495
# 감세액              58
# 감세액 비율         11.7
# 이월건수             28
# Name: 0, dtype: object

# %%
df_tax.head() # 상위 데이터 추출
# Out:
#         구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액   감세액  \
# 0  청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495    58
# 1  청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488   162
# 2  청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964   337
# 3  청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875   686
# 4  청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505  4567
#
#    감세액 비율  이월건수
# 0    11.7    28
# 1    10.9    18
# 2    17.2    10
# 3    14.1    21
# 4    17.9    43

# %%
df_tax.tail() # 하위 데이터 추출
# Out:
#    구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률  처리세액   감세액  \
# 16  법인  5천만 미만        0       13      1     11      0   0.0   482     0
# 17  법인   1억 미만        7       11      0     12      4  25.0  1165   180
# 18  법인   5억 미만       11       30      2     20      4  15.4  6818   702
# 19  법인  10억 미만        2        6      1      3      2  33.3  4418  1394
# 20  법인  10억 이상        5        1      0      2      2  50.0  6292  1454
#
#     감세액 비율  이월건수
# 16     0.0     1
# 17    15.5     2
# 18    10.3    15
# 19    31.6     2
# 20    23.1     2

# %%
df_tax.index # 데이터프레임 인덱스 보기
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
df_tax.values # 행, 열 구조 보기
# Out:
# array([['청구세액 규모별', '1천만 미만', 44, 131, 24, 107, 16, 10.9, 495, 58, 11.7,
#         28],
#        ['청구세액 규모별', '3천만 미만', 23, 78, 5, 65, 13, 15.7, 1488, 162, 10.9,
#         18],
#        ['청구세액 규모별', '5천만 미만', 6, 54, 6, 34, 10, 20.0, 1964, 337, 17.2,
#         10],
#        ['청구세액 규모별', '1억 미만', 15, 74, 8, 49, 11, 16.2, 4875, 686, 14.1,
#         21],
#        ['청구세액 규모별', '5억 미만', 31, 119, 8, 72, 27, 25.2, 25505, 4567, 17.9,
#         43],
#        ['청구세액 규모별', '10억 미만', 4, 24, 1, 11, 3, 20.0, 10598, 1494, 14.1,
#         13],
#        ['청구세액 규모별', '10억 이상', 6, 9, 0, 7, 3, 30.0, 17309, 1460, 8.4, 5],
#        ['개인', '1천만 미만', 40, 121, 23, 96, 15, 11.2, 439, 49, 11.2, 27],
#        ['개인', '3천만 미만', 21, 58, 2, 52, 12, 18.2, 1181, 160, 13.5, 13],
#        ['개인', '5천만 미만', 6, 41, 5, 23, 10, 26.3, 1482, 337, 22.7, 9],
#        ['개인', '1억 미만', 8, 63, 8, 37, 7, 13.5, 3710, 506, 13.6, 19],
#        ['개인', '5억 미만', 20, 89, 6, 52, 23, 28.4, 18687, 3865, 20.7, 28],
# ...

# %%
df_no_taxes1.values # 행, 열 구조 보기
# Out:
# array([['지역별', '서울', 1274, 11274],
#        ['지역별', '인천', 492, 4160],
#        ['지역별', '경기', 2326, 16416],
#        ['지역별', '강원', 125, 762],
#        ['지역별', '대전', 149, 918],
#        ['지역별', '충북', 166, 932],
#        ['지역별', '충남', 311, 1778],
#        ['지역별', '세종', 38, 223],
#        ['지역별', '광주', 159, 1354],
#        ['지역별', '전북', 176, 1011],
#        ['지역별', '전남', 174, 1361],
#        ['지역별', '대구', 214, 1186],
#        ['지역별', '경북', 280, 3491],
#        ['지역별', '부산', 376, 4203],
#        ['지역별', '울산', 167, 980],
#        ['지역별', '경남', 429, 2461],
#        ['지역별', '제주', 160, 1102],
#        ['체납액 규모별', '2억 이상', 4734, 16100],
#        ['체납액 규모별', '5억 이상', 1463, 9899],
#        ['체납액 규모별', '10억 이상', 740, 13311],
#        ['체납액 규모별', '50억 이상', 41, 2784],
#        ['체납액 규모별', '100억 이상', 38, 11518],
#        ['체납자 유형별', '법인', 2314, 15254],
#        ['체납자 유형별', '개인 30세 미만', 48, 219],
#        ['체납자 유형별', '개인 30세 이상', 371, 6744],
#        ['체납자 유형별', '개인 40세 이상', 1140, 7833],
# ...

# %%
df_tax.sort_values(by=['전년이월 건수'], axis=0) # 전년이월 건수 기준 오름차순 정렬
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 16        법인  5천만 미만        0       13      1     11      0   0.0    482
# 13        개인  10억 이상        1        8      0      5      1  16.7  11017
# 15        법인  3천만 미만        2       20      3     13      1   5.9    307
# 19        법인  10억 미만        2        6      1      3      2  33.3   4418
# 12        개인  10억 미만        2       18      0      8      1  11.1   6180
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 14        법인  1천만 미만        4       10      1     11      1   7.7     56
# 20        법인  10억 이상        5        1      0      2      2  50.0   6292
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 17        법인   1억 미만        7       11      0     12      4  25.0   1165
# ...

# %%
df_tax.sort_values(by=['전년이월 건수'], axis=0, ascending=False) # 전년이월 건수 기준 내림차순 정렬
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 18        법인   5억 미만       11       30      2     20      4  15.4   6818
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 17        법인   1억 미만        7       11      0     12      4  25.0   1165
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# ...

# %%
df_tax.sort_values(by=['인용률'], axis=0) # 인용률 기준 오름차순 정렬
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 16        법인  5천만 미만        0       13      1     11      0   0.0    482
# 15        법인  3천만 미만        2       20      3     13      1   5.9    307
# 14        법인  1천만 미만        4       10      1     11      1   7.7     56
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 12        개인  10억 미만        2       18      0      8      1  11.1   6180
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 18        법인   5억 미만       11       30      2     20      4  15.4   6818
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 13        개인  10억 이상        1        8      0      5      1  16.7  11017
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# ...

# %%
df_tax.sort_values(by=['인용률'], axis=0, ascending=False) # 인용률 기준 내림차순 정렬
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 20        법인  10억 이상        5        1      0      2      2  50.0   6292
# 19        법인  10억 미만        2        6      1      3      2  33.3   4418
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 17        법인   1억 미만        7       11      0     12      4  25.0   1165
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 13        개인  10억 이상        1        8      0      5      1  16.7  11017
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# ...

# %%
df_no_taxes.describe() #데이터프레임의 기초 통계 확인
# Out:
#            당해연도 인원  당해연도 납부세액(억원)         누계 인원   누계 납부세액(억원)
# count     7.000000       7.000000      7.000000      7.000000
# mean    798.142857     436.428571   5717.571429   3702.285714
# std     446.260547     345.133239   4447.311430   3782.502642
# min     320.000000     109.000000   2055.000000   1056.000000
# 25%     449.500000     208.500000   2795.000000   1368.000000
# 50%     742.000000     347.000000   3511.000000   1418.000000
# 75%    1083.500000     564.000000   8085.500000   4953.000000
# max    1459.000000    1054.000000  12696.000000  10800.000000

# %%
df_no_taxes.dtypes # 데이터유형 확인
# Out:
# 구분               object
# 당해연도 인원           int64
# 당해연도 납부세액(억원)     int64
# 누계 인원             int64
# 누계 납부세액(억원)       int64
# dtype: object

# %%
df_no_taxes.loc[0] # 데이터 행 인덱스 확인
# Out:
# 구분                 서울청
# 당해연도 인원           1459
# 당해연도 납부세액(억원)     1054
# 누계 인원            12696
# 누계 납부세액(억원)      10800
# Name: 0, dtype: object

# %%
df_no_taxes.head() # 상위 데이터 추출
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 0  서울청     1459           1054  12696        10800
# 1  중부청     1300            766  11441         7100
# 2  인천청      867            362   3456         1363
# 3  대전청      565            213   3511         1373
# 4  광주청      334            204   2134         1418

# %%
df_no_taxes.tail() # 하위 데이터 추출
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 2  인천청      867            362   3456         1363
# 3  대전청      565            213   3511         1373
# 4  광주청      334            204   2134         1418
# 5  대구청      320            109   2055         1056
# 6  부산청      742            347   4730         2806

# %%
df_no_taxes.index # 데이터프레임 인덱스 보기
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df_no_taxes.values # 행, 열 구조 보기
# Out:
# array([['서울청', 1459, 1054, 12696, 10800],
#        ['중부청', 1300, 766, 11441, 7100],
#        ['인천청', 867, 362, 3456, 1363],
#        ['대전청', 565, 213, 3511, 1373],
#        ['광주청', 334, 204, 2134, 1418],
#        ['대구청', 320, 109, 2055, 1056],
#        ['부산청', 742, 347, 4730, 2806]], dtype=object)

# %%
df_no_taxes.sort_values(by=['당해연도 인원'], axis=0) # 당해연도 인원 기준 오름차순 정렬
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 5  대구청      320            109   2055         1056
# 4  광주청      334            204   2134         1418
# 3  대전청      565            213   3511         1373
# 6  부산청      742            347   4730         2806
# 2  인천청      867            362   3456         1363
# 1  중부청     1300            766  11441         7100
# 0  서울청     1459           1054  12696        10800

# %%
df_no_taxes.sort_values(by=['당해연도 인원'], axis=0, ascending=False) # 당해연도 인원 기준 내림차순 정렬
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)
# 0  서울청     1459           1054  12696        10800
# 1  중부청     1300            766  11441         7100
# 2  인천청      867            362   3456         1363
# 6  부산청      742            347   4730         2806
# 3  대전청      565            213   3511         1373
# 4  광주청      334            204   2134         1418
# 5  대구청      320            109   2055         1056

# %% [markdown]
# # **데이터 클린징**

# %%
df_tax.count() # 데이터 갯수 확인
# Out:
# 구분1        21
# 구분2        21
# 전년이월 건수    21
# 당년접수 건수    21
# 각하 건수      21
# 기각 건수      21
# 인용 건수      21
# 인용률        21
# 처리세액       21
# 감세액        21
# 감세액 비율     21
# 이월건수       21
# dtype: int64

# %%
df_no_taxes.count() # 데이터 갯수 확인
# Out:
# 구분               7
# 당해연도 인원          7
# 당해연도 납부세액(억원)    7
# 누계 인원            7
# 누계 납부세액(억원)      7
# dtype: int64

# %%
df_tax.isnull().sum() # 결측치 확인
# Out:
# 구분1        0
# 구분2        0
# 전년이월 건수    0
# 당년접수 건수    0
# 각하 건수      0
# 기각 건수      0
# 인용 건수      0
# 인용률        0
# 처리세액       0
# 감세액        0
# 감세액 비율     0
# 이월건수       0
# dtype: int64

# %%
df_no_taxes.isnull().sum() # 결측치 확인
# Out:
# 구분               0
# 당해연도 인원          0
# 당해연도 납부세액(억원)    0
# 누계 인원            0
# 누계 납부세액(억원)      0
# dtype: int64

# %%
### 해당 데이터에 결측치가 존재하지 않는다는 것을 확인한다. ###
### 확인 결과 데이터에 결측치가 없어서 대체, 제거가 불가능하다는 것을 확인할 수 있다. ###

# %% [markdown]
# # **데이터 탐색**

# %%
# 전체를 3개 범주로 구분
df_tax_bulbog = pd.qcut(df_tax["인용 건수"], q=3, labels =["잘함", "평균", "못함"])
df_tax["인용 건수 분류"] = df_tax_bulbog
df_tax
# Out:
#          구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액  \
# 0   청구세액 규모별  1천만 미만       44      131     24    107     16  10.9    495
# 1   청구세액 규모별  3천만 미만       23       78      5     65     13  15.7   1488
# 2   청구세액 규모별  5천만 미만        6       54      6     34     10  20.0   1964
# 3   청구세액 규모별   1억 미만       15       74      8     49     11  16.2   4875
# 4   청구세액 규모별   5억 미만       31      119      8     72     27  25.2  25505
# 5   청구세액 규모별  10억 미만        4       24      1     11      3  20.0  10598
# 6   청구세액 규모별  10억 이상        6        9      0      7      3  30.0  17309
# 7         개인  1천만 미만       40      121     23     96     15  11.2    439
# 8         개인  3천만 미만       21       58      2     52     12  18.2   1181
# 9         개인  5천만 미만        6       41      5     23     10  26.3   1482
# 10        개인   1억 미만        8       63      8     37      7  13.5   3710
# 11        개인   5억 미만       20       89      6     52     23  28.4  18687
# ...

# %%
# 데이터프레임 복사
df_copy = df_tax

# "금액 구분"이라는 열을 추가하고 중복된 값을 제거
df_copy["금액 구분"] = df_copy.drop_duplicates(['구분2'], keep='first')["구분2"]
df_tax = df_copy

# %%
# 구분1, 구분2, 처리세액 그룹에 의한 인용률을 데이터프레임으로 계산한다.
# 행에는 구분1 및 처리세액 그룹에 대한 다중 인덱스를 사용하고 열에는 인용률 인덱스를 사용한다.
df1 = df_tax.groupby(['구분1','구분2','처리세액'])["인용률"].mean()
df1
# Out:
# 구분1       구분2     처리세액
# 개인        10억 미만  6180     11.1
#           10억 이상  11017    16.7
#           1억 미만   3710     13.5
#           1천만 미만  439      11.2
#           3천만 미만  1181     18.2
#           5억 미만   18687    28.4
#           5천만 미만  1482     26.3
# 법인        10억 미만  4418     33.3
#           10억 이상  6292     50.0
#           1억 미만   1165     25.0
#           1천만 미만  56        7.7
#           3천만 미만  307       5.9
#           5억 미만   6818     15.4
#           5천만 미만  482       0.0
# 청구세액 규모별  10억 미만  10598    20.0
#           10억 이상  17309    30.0
#           1억 미만   4875     16.2
#           1천만 미만  495      10.9
#           3천만 미만  1488     15.7
#           5억 미만   25505    25.2
#           5천만 미만  1964     20.0
# Name: 인용률, dtype: float64

# %%
df2 = df1.unstack("구분1")
df2
# Out:
# 구분1             개인    법인  청구세액 규모별
# 구분2    처리세액
# 10억 미만 4418    NaN  33.3       NaN
#        6180   11.1   NaN       NaN
#        10598   NaN   NaN      20.0
# 10억 이상 6292    NaN  50.0       NaN
#        11017  16.7   NaN       NaN
#        17309   NaN   NaN      30.0
# 1억 미만  1165    NaN  25.0       NaN
#        3710   13.5   NaN       NaN
#        4875    NaN   NaN      16.2
# 1천만 미만 56      NaN   7.7       NaN
#        439    11.2   NaN       NaN
#        495     NaN   NaN      10.9
# 3천만 미만 307     NaN   5.9       NaN
#        1181   18.2   NaN       NaN
#        1488    NaN   NaN      15.7
# 5억 미만  6818    NaN  15.4       NaN
#        18687  28.4   NaN       NaN
#        25505   NaN   NaN      25.2
# 5천만 미만 482     NaN   0.0       NaN
#        1482   26.3   NaN       NaN
#        1964    NaN   NaN      20.0

# %%
df_tax_copy_backup1.drop(df_tax_copy_backup1.index[0:7], inplace=True)
df_tax_copy_backup1
# Out:
#    구분1     구분2  전년이월 건수  당년접수 건수  각하 건수  기각 건수  인용 건수   인용률   처리세액   감세액  \
# 7   개인  1천만 미만       40      121     23     96     15  11.2    439    49
# 8   개인  3천만 미만       21       58      2     52     12  18.2   1181   160
# 9   개인  5천만 미만        6       41      5     23     10  26.3   1482   337
# 10  개인   1억 미만        8       63      8     37      7  13.5   3710   506
# 11  개인   5억 미만       20       89      6     52     23  28.4  18687  3865
# 12  개인  10억 미만        2       18      0      8      1  11.1   6180   100
# 13  개인  10억 이상        1        8      0      5      1  16.7  11017     6
# 14  법인  1천만 미만        4       10      1     11      1   7.7     56     9
# 15  법인  3천만 미만        2       20      3     13      1   5.9    307     2
# 16  법인  5천만 미만        0       13      1     11      0   0.0    482     0
# 17  법인   1억 미만        7       11      0     12      4  25.0   1165   180
# 18  법인   5억 미만       11       30      2     20      4  15.4   6818   702
# ...

# %%
df_no_taxes["1인당 누계량"] = df_no_taxes['누계 납부세액(억원)'] / df_no_taxes['누계 인원']

# %%
df_no_taxes["당해 1인당 납부액"] = df_no_taxes['당해연도 납부세액(억원)'] / df_no_taxes['당해연도 인원']

# %%
df_no_taxes["22년도 고액상습체납금 평균"] = ( df_no_taxes['누계 납부세액(억원)'] + df_no_taxes['당해연도 납부세액(억원)'] ) / (df_no_taxes['누계 인원'] + df_no_taxes['당해연도 인원'])

# %%
df_no_taxes
# Out:
#     구분  당해연도 인원  당해연도 납부세액(억원)  누계 인원  누계 납부세액(억원)   1인당 누계량  당해 1인당 납부액  \
# 0  서울청     1459           1054  12696        10800  0.850662    0.722413
# 1  중부청     1300            766  11441         7100  0.620575    0.589231
# 2  인천청      867            362   3456         1363  0.394387    0.417532
# 3  대전청      565            213   3511         1373  0.391057    0.376991
# 4  광주청      334            204   2134         1418  0.664480    0.610778
# 5  대구청      320            109   2055         1056  0.513869    0.340625
# 6  부산청      742            347   4730         2806  0.593235    0.467655
#
#    22년도 고액상습체납금 평균
# 0         0.837443
# 1         0.617377
# 2         0.399028
# 3         0.389107
# 4         0.657212
# 5         0.490526
# 6         0.576206

# %%
df_no_taxes.pivot_table(['22년도 고액상습체납금 평균'],index=['구분', '당해연도 납부세액(억원)'], aggfunc='mean')
# Out:
#                    22년도 고액상습체납금 평균
# 구분  당해연도 납부세액(억원)
# 광주청 204                   0.657212
# 대구청 109                   0.490526
# 대전청 213                   0.389107
# 부산청 347                   0.576206
# 서울청 1054                  0.837443
# 인천청 362                   0.399028
# 중부청 766                   0.617377

# %% [markdown]
# # **데이터 시각화 분석**

# %%
# 한글처리
plt.rc('font', family='Malgun Gothic')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set NanumGothic as the default font
plt.rcParams["font.family"] = 'NanumGothic'

# %%
#커널밀도함수
#sns.kdeplot(데이터프레임.변수)
# --> tips 데이터 프레임에 있는 tip 데이터의 분포를 시각화(kdeplot)하는 문장 작성
sns.kdeplot(df_tax.인용률)
#ns.catplot('구분1',kind='count',data=df_tax)
# Out:
# <Axes: xlabel='인용률', ylabel='Density'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming "인용 건수" and "구분1" are correct column names in your DataFrame
sns.catplot(x='인용 건수', kind='count', hue='구분1', data=df_tax_copy_backup1)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# Assuming "인용 건수" and "구분1" are correct column names in your DataFrame
sns.catplot(x='인용 건수', y='인용률', kind='point', hue='구분1', data=df_tax_copy_backup1)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 47456 (\N{HANGUL SYLLABLE RYUL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
# Assuming "인용 건수" and "구분1" are correct column names in your DataFrame
sns.catplot(x='인용 건수', kind='count', hue='구분2', data=df_tax_copy_backup1)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
# Assuming "인용 건수" and "구분1" are correct column names in your DataFrame
sns.catplot(x='인용 건수', y='처리세액', kind='bar', hue='구분2', data=df_tax_copy_backup1)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
df_tax_copy_backup1['이월건수'].hist()
# Out:
# <Axes: >
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create a bar plot
sns.barplot(x='구분2', y='인용률', data=df_tax, ci=None, palette='viridis')
# Out:
# <ipython-input-78-b140cdc164c8>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='구분2', y='인용률', data=df_tax, ci=None, palette='viridis')
# <Axes: xlabel='구분2', ylabel='인용률'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create a scatter plot with regression line
sns.regplot(x='처리세액', y='인용률', data=df_tax, scatter_kws={'s': 10}, line_kws={'color': 'red'})

# Set plot title and labels
plt.title('Relationship between 처리세액 and 인용률')
plt.xlabel('처리세액')
plt.ylabel('인용률')

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
# ...

# %% [markdown]
# ***전체를 한번에 표시***

# %%
# Extract relevant columns
df_subset = df_tax[['구분1', '구분2', '처리세액', '인용률']]

# Group by '구분1', '구분2', '처리세액' and calculate mean 인용률
grouped_data = df_subset.groupby(['구분1', '구분2', '처리세액']).mean().reset_index()

import seaborn as sns
import matplotlib.pyplot as plt

# Set up the figure
plt.figure(figsize=(12, 8))

# Create a heatmap to visualize the impact of '구분1', '구분2', '처리세액' on 인용률
sns.heatmap(data=grouped_data.pivot('구분2', '구분1', '인용률'), annot=True, cmap='YlGnBu', fmt=".1f", linewidths=.5)

# Set plot title and labels
plt.title('Impact of 구분1, 구분2, 처리세액 on 인용률')
plt.xlabel('구분1')
plt.ylabel('구분2')

# Show the plot
plt.show()
# Out:
# <ipython-input-77-0500b50b8de1>:14: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(data=grouped_data.pivot('구분2', '구분1', '인용률'), annot=True, cmap='YlGnBu', fmt=".1f", linewidths=.5)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 48277 (\N{HANGUL SYLLABLE BEOB}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
sns.barplot(x='구분2', y='이월건수', data=df_tax , palette='viridis')
# Out:
# <Axes: xlabel='구분2', ylabel='이월건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
sns.barplot(x='구분2', y='당년접수 건수', data=df_tax , palette='viridis')
# Out:
# <Axes: xlabel='구분2', ylabel='당년접수 건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 금액은 이월건수와 당년범수 건수와는 상관관계가 없다.

# %%
# Calculate the sum of 이월건수 and 당년접수 건수 for each 구분2
grouped_data = df_tax.groupby('구분2')['이월건수', '당년접수 건수'].sum().reset_index()

# Set up the figure
plt.figure(figsize=(12, 6))

# Create a scatter plot
sns.scatterplot(x='이월건수', y='당년접수 건수', hue='구분2', data=grouped_data, palette='viridis')
# Out:
# <ipython-input-82-3e7a943cb689>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_data = df_tax.groupby('구분2')['이월건수', '당년접수 건수'].sum().reset_index()
# <Axes: xlabel='이월건수', ylabel='당년접수 건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#각하 건수와 당년접수 건수의 관계
sns.scatterplot(x='각하 건수', y='당년접수 건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='각하 건수', ylabel='당년접수 건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#각하 건수와 이월건수의 관계
sns.scatterplot(x='각하 건수', y='이월건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='각하 건수', ylabel='이월건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#기각 건수와 당년접수 건수의 관계
sns.scatterplot(x='기각 건수', y='당년접수 건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='기각 건수', ylabel='당년접수 건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#기각 건수와 이월건수의 관계
sns.scatterplot(x='기각 건수', y='이월건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='기각 건수', ylabel='이월건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
# Calculate the sum of 각하 건수 and 기각 건수 for each row
df_tax['각하_기각_합계'] = df_tax['각하 건수'] + df_tax['기각 건수']

# Calculate the sum of 당년접수 건수 and 이월건수 for each row
df_tax['당년_이월_합계'] = df_tax['당년접수 건수'] + df_tax['이월건수']

# %%
#각하_기각_합계와 당년접수 건수의 관계
sns.scatterplot(x='각하_기각_합계', y='당년접수 건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='각하_기각_합계', ylabel='당년접수 건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#각하_기각_합계와 이월건수의 관계
sns.scatterplot(x='각하_기각_합계', y='이월건수', data=df_tax, hue='구분2', palette='viridis')
# Out:
# <Axes: xlabel='각하_기각_합계', ylabel='이월건수'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 각하 건수 + 기각 건수를 합한 값은 당년접수 건수 + 이월건수의 값에 영향을 주는 것을 확인할 수 있다.

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create a scatter plot
sns.scatterplot(x='각하_기각_합계', y='당년_이월_합계', data=df_tax, hue='구분2', palette='viridis')

# Set plot title and labels
plt.title('Relationship between 각하/기각 합계 and 당년/이월 합계')
plt.xlabel('각하/기각 합계')
plt.ylabel('당년/이월 합계')

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#누계 납부세액(억원)을 막대그래프
sns.barplot(x='구분', y='누계 납부세액(억원)', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='누계 납부세액(억원)'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
#누계 인원을 막대그래프
sns.barplot(x='구분', y='누계 인원', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='누계 인원'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# # 누계 1인당 금액은 인구수가 밀집된 서울청이 가장 높다.

# %%
sns.barplot(x='구분', y='1인당 누계량', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='1인당 누계량'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
#당해연도 납부세액(억원)을 막대그래프
sns.barplot(x='구분', y='당해연도 납부세액(억원)', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='당해연도 납부세액(억원)'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
#당해연도 인원을 막대그래프
sns.barplot(x='구분', y='당해연도 인원', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='당해연도 인원'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# # 인구수가 많은 도시(서울청)가 당해년도 1인당 금액이 높다.

# %%
sns.barplot(x='구분', y='당해 1인당 납부액', data=df_no_taxes, palette='viridis')
# Out:
# <Axes: xlabel='구분', ylabel='당해 1인당 납부액'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
avg_personnel = df_no_taxes['당해연도 인원'].mean()
df_no_taxes['Exceeds_Avg_Personnel'] = df_no_taxes['당해연도 인원'] > avg_personnel

# %%
avg_tax_payment = df_no_taxes['당해연도 납부세액(억원)'].mean()
df_no_taxes['Exceeds_Avg_Tax_Payment'] = df_no_taxes['당해연도 납부세액(억원)'] > avg_tax_payment

# %%
plt.figure(figsize=(12, 6))

# Create a bar plot for 당해연도 인원
sns.barplot(x='구분', y='당해연도 인원', data=df_no_taxes, palette='viridis')

# Add a horizontal line for the average
plt.axhline(avg_personnel, color='red', linestyle='dashed', linewidth=2, label=f'Average: {avg_personnel:.2f}')

# Set plot title and labels
plt.title('당해연도 인원 with Average')
plt.xlabel('구분')
plt.ylabel('당해연도 인원')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
# ...

# %%
sns.barplot(x='구분', y='당해연도 인원', data=df_no_taxes, palette=df_no_taxes['Exceeds_Avg_Personnel'].map({True: 'red', False: 'green'}))
# Out:
# <Axes: xlabel='구분', ylabel='당해연도 인원'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
plt.figure(figsize=(12, 6))

# Create a bar plot for 당해연도 납부세액(억원)
sns.barplot(x='구분', y='당해연도 납부세액(억원)', data=df_no_taxes, palette='viridis')

# Add a horizontal line for the average
plt.axhline(avg_tax_payment, color='red', linestyle='dashed', linewidth=2, label=f'Average: {avg_tax_payment:.2f}')

# Set plot title and labels
plt.title('당해연도 납부세액(억원) with Average')
plt.xlabel('구분')
plt.ylabel('당해연도 납부세액(억원)')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.barplot(x='구분', y='당해연도 납부세액(억원)', data=df_no_taxes, palette=df_no_taxes['Exceeds_Avg_Tax_Payment'].map({True: 'red', False: 'green'}))
# Out:
# <Axes: xlabel='구분', ylabel='당해연도 납부세액(억원)'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   func(*args, **kwargs)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# #	당해연도 인원과 당해연도 납부세액(억원)의 평균 이상을 보인 곳은 서울청과 중부청 두 곳이다.

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create a grouped bar plot for both 당해연도 인원 and 당해연도 납부세액(억원)
sns.barplot(x='구분', y='당해연도 인원', data=df_no_taxes, hue='Exceeds_Avg_Personnel', palette={True: 'red', False: 'green'}, dodge=True, alpha=0.7)
sns.barplot(x='구분', y='당해연도 납부세액(억원)', data=df_no_taxes, hue='Exceeds_Avg_Tax_Payment', palette={True: 'blue', False: 'orange'}, dodge=True, alpha=0.7)

# Add horizontal lines for the averages
plt.axhline(avg_personnel, color='red', linestyle='dashed', linewidth=2, label=f'Avg Personnel: {avg_personnel:.2f}')
plt.axhline(avg_tax_payment, color='blue', linestyle='dashed', linewidth=2, label=f'Avg Tax Payment: {avg_tax_payment:.2f}')

# Set plot title and labels
plt.title('Comparison with Average - 당해연도 인원 and 당해연도 납부세액(억원)')
plt.xlabel('구분')
plt.ylabel('Values')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
# Calculate the averages
avg_total_personnel = df_no_taxes['누계 인원'].mean()
avg_total_tax_payment = df_no_taxes['누계 납부세액(억원)'].mean()

# Create columns indicating if each category exceeds the averages
df_no_taxes['Exceeds_Avg_Total_Personnel'] = df_no_taxes['누계 인원'] > avg_total_personnel
df_no_taxes['Exceeds_Avg_Total_Tax_Payment'] = df_no_taxes['누계 납부세액(억원)'] > avg_total_tax_payment

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create bar plot for 누계 인원
sns.barplot(x='구분', y='누계 인원', data=df_no_taxes, palette=df_no_taxes['Exceeds_Avg_Total_Personnel'].map({True: 'red', False: 'green'}))

# Add a horizontal line for the average of 누계 인원
plt.axhline(avg_total_personnel, color='blue', linestyle='dashed', linewidth=2, label=f'Avg Total Personnel: {avg_total_personnel:.2f}')

# Set plot title and labels
plt.title('Comparison with Average - 누계 인원')
plt.xlabel('구분')
plt.ylabel('누계 인원')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Set up the figure for 누계 납부세액(억원)
plt.figure(figsize=(12, 6))

# Create bar plot for 누계 납부세액(억원)
sns.barplot(x='구분', y='누계 납부세액(억원)', data=df_no_taxes, palette=df_no_taxes['Exceeds_Avg_Total_Tax_Payment'].map({True: 'red', False: 'green'}))

# Add a horizontal line for the average of 누계 납부세액(억원)
plt.axhline(avg_total_tax_payment, color='blue', linestyle='dashed', linewidth=2, label=f'Avg Total Tax Payment: {avg_total_tax_payment:.2f}')

# Set plot title and labels
plt.title('Comparison with Average - 누계 납부세액(억원)')
plt.xlabel('구분')
plt.ylabel('누계 납부세액(억원)')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
# ...

# %% [markdown]
# # 누계 인원, 누계 납부세액(억원)의 평균 이상을 보인 곳은 서울청과 중부청 두 곳이다.

# %%
# Set up the figure
plt.figure(figsize=(12, 6))

# Create a grouped bar plot for both 누계 인원 and 누계 납부세액(억원)
sns.barplot(x='구분', y='누계 인원', data=df_no_taxes, hue='Exceeds_Avg_Total_Personnel', palette={True: 'red', False: 'green'}, dodge=True, alpha=0.7)
sns.barplot(x='구분', y='누계 납부세액(억원)', data=df_no_taxes, hue='Exceeds_Avg_Total_Tax_Payment', palette={True: 'blue', False: 'orange'}, dodge=True, alpha=0.7)

# Add horizontal lines for the averages
plt.axhline(avg_total_personnel, color='red', linestyle='dashed', linewidth=2, label=f'Avg Total Personnel: {avg_total_personnel:.2f}')
plt.axhline(avg_total_tax_payment, color='blue', linestyle='dashed', linewidth=2, label=f'Avg Total Tax Payment: {avg_total_tax_payment:.2f}')

# Set plot title and labels
plt.title('Comparison with Average - 누계 인원 and 누계 납부세액(억원)')
plt.xlabel('구분')
plt.ylabel('Values')

# Add legend
plt.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
print(df_no_taxes1.head())
# Out:
#    구분1 구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 0  지역별  서울      1274            11274
# 1  지역별  인천       492             4160
# 2  지역별  경기      2326            16416
# 3  지역별  강원       125              762
# 4  지역별  대전       149              918

# %%
df_no_taxes1
# Out:
#         구분1        구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 0       지역별         서울      1274            11274
# 1       지역별         인천       492             4160
# 2       지역별         경기      2326            16416
# 3       지역별         강원       125              762
# 4       지역별         대전       149              918
# 5       지역별         충북       166              932
# 6       지역별         충남       311             1778
# 7       지역별         세종        38              223
# 8       지역별         광주       159             1354
# 9       지역별         전북       176             1011
# 10      지역별         전남       174             1361
# 11      지역별         대구       214             1186
# 12      지역별         경북       280             3491
# 13      지역별         부산       376             4203
# 14      지역별         울산       167              980
# 15      지역별         경남       429             2461
# 16      지역별         제주       160             1102
# 17  체납액 규모별      2억 이상      4734            16100
# ...

# %%
# Create a new DataFrame by copying the original
df_filtered = df_no_taxes1.copy()

# Select rows where '구분1' is either '체납액 규모별' or '체납자 유형별'
df_filtered = df_filtered[df_filtered['구분1'].isin(['체납액 규모별', '체납자 유형별'])]

df_filtered
# Out:
#         구분1        구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 17  체납액 규모별      2억 이상      4734          16100.0
# 18  체납액 규모별      5억 이상      1463           9899.0
# 19  체납액 규모별     10억 이상       740          13311.0
# 20  체납액 규모별     50억 이상        41           2784.0
# 21  체납액 규모별    100억 이상        38          11518.0
# 22  체납자 유형별         법인      2314          15254.0
# 23  체납자 유형별  개인 30세 미만        48            219.0
# 24  체납자 유형별  개인 30세 이상       371           6744.0
# 25  체납자 유형별  개인 40세 이상      1140           7833.0
# 26  체납자 유형별  개인 50세 이상      1581          12012.0
# 27  체납자 유형별  개인 60세 이상      1552          11495.0
# 28  체납자 유형별      개인 기타        10             55.0

# %%
# Select rows where '구분1' is '체납자 유형별'
df_cheonap_type = df_filtered[df_filtered['구분1'] == '체납자 유형별']

# Calculate the average of '신규공개자 체납세액 (억원)'
avg_cheonap = df_cheonap_type['신규공개자 체납세액 (억원)'].mean()

# Split the data into rows with amounts above and below the average
above_avg = df_cheonap_type[df_cheonap_type['신규공개자 체납세액 (억원)'] > avg_cheonap]
below_avg = df_cheonap_type[df_cheonap_type['신규공개자 체납세액 (억원)'] <= avg_cheonap]

# %%
# Visualization
plt.figure(figsize=(8, 6))
sns.barplot(x=['Average'], y=[avg_cheonap], color='blue')
plt.text(0, avg_cheonap + 1, f'Average: {avg_cheonap:.2f}', ha='center', va='bottom', fontsize=10, color='black')
plt.title('Average Value of 신규공개자 체납세액 (억원)')
plt.ylabel('신규공개자 체납세액 (억원)')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x='구분1', y='신규공개자 체납세액 (억원)', data=df_cheonap_type, ci=None, palette='viridis')
plt.axhline(avg_cheonap, color='red', linestyle='dashed', linewidth=2, label=f'Average: {avg_cheonap:.2f}')
plt.scatter(above_avg.index, above_avg['신규공개자 체납세액 (억원)'], color='red', marker='o', label='Above Average')
plt.scatter(below_avg.index, below_avg['신규공개자 체납세액 (억원)'], color='green', marker='o', label='Below Average')

# Annotate values slightly above the data points
for index, value in above_avg.iterrows():
    plt.text(index, value['신규공개자 체납세액 (억원)'] + 5, f'{value["신규공개자 체납세액 (억원)"]:.2f}', ha='center', va='bottom', fontsize=8, color='red')

for index, value in below_avg.iterrows():
    plt.text(index, value['신규공개자 체납세액 (억원)'] + 5, f'{value["신규공개자 체납세액 (억원)"]:.2f}', ha='center', va='bottom', fontsize=8, color='green')

plt.title('Comparison of Average and Individual Values for 신규공개자 체납세액 (억원) by 체납자 유형별')
plt.xlabel('체납자 유형별')
plt.ylabel('신규공개자 체납세액 (억원)')
plt.legend()
plt.show()
# Out:
# <ipython-input-141-5b93689bde0a>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='구분1', y='신규공개자 체납세액 (억원)', data=df_cheonap_type, ci=None, palette='viridis')
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# Create a copy of the original dataframe
df_copy = df_no_taxes1.copy()

# Extract age groups and 체납세액 columns
age_groups = df_copy['구분1']
cheonap_amounts = df_copy['신규공개자 체납세액 (억원)']

# Find the index of the maximum 체납세액 for each age group
max_amount_indices = df_copy.groupby('구분1')['신규공개자 체납세액 (억원)'].idxmax()

# Create a DataFrame with only rows containing maximum 체납세액 for each age group
df_max_amounts = df_copy.loc[max_amount_indices]

# Calculate the average of '신규공개자 체납세액 (억원)'
avg_cheonap = df_copy['신규공개자 체납세액 (억원)'].mean()

# Determine colors based on whether values are above or below the average
colors = ['red' if value > avg_cheonap else 'blue' for value in df_copy['신규공개자 체납세액 (억원)']]

# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x=df_copy.index, y='신규공개자 체납세액 (억원)', data=df_copy, palette=colors)
plt.scatter(df_max_amounts.index, df_max_amounts['신규공개자 체납세액 (억원)'], color='green', marker='o', label='Maximum Amounts')
plt.axhline(avg_cheonap, color='black', linestyle='dashed', linewidth=2, label=f'Average: {avg_cheonap:.2f}')
plt.title('Comparison of Individual Values with Average for 신규공개자 체납세액 (억원)')
plt.xlabel('Data Index')
plt.ylabel('신규공개자 체납세액 (억원)')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
df_filtered = df_copy[df_copy['구분2'].str.contains('개인')]
df_filtered
# Out:
#         구분1        구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 23  체납자 유형별  개인 30세 미만        48            219.0
# 24  체납자 유형별  개인 30세 이상       371           6744.0
# 25  체납자 유형별  개인 40세 이상      1140           7833.0
# 26  체납자 유형별  개인 50세 이상      1581          12012.0
# 27  체납자 유형별  개인 60세 이상      1552          11495.0
# 28  체납자 유형별      개인 기타        10             55.0

# %% [markdown]
# # **나이별 체납세액 (억원)의 평균을 넘긴 데이터를 찾아 시각화하려 했으나 결과가 올바르게 나오지 않음**

# %%
# Calculate the average of '신규공개자 체납세액 (억원)'
avg_cheonap = df_filtered['신규공개자 체납세액 (억원)'].mean()

# Determine colors based on whether values are above or below the average
colors = ['red' if value > avg_cheonap else 'blue' for value in df_filtered['신규공개자 체납세액 (억원)']]

# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x=df_filtered.index, y='신규공개자 체납세액 (억원)', data=df_filtered, palette=colors)
plt.axhline(avg_cheonap, color='black', linestyle='dashed', linewidth=2, label=f'Average: {avg_cheonap:.2f}')
plt.title('Comparison of Individual Values with Average for 신규공개자 체납세액 (억원) for "개인"')
plt.xlabel('Data Index')
plt.ylabel('신규공개자 체납세액 (억원)')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df_subset = df_no_taxes1.loc[0:16]
df_subset
# Out:
#     구분1 구분2  신규공개자 인원  신규공개자 체납세액 (억원)
# 0   지역별  서울      1274          11274.0
# 1   지역별  인천       492           4160.0
# 2   지역별  경기      2326          16416.0
# 3   지역별  강원       125            762.0
# 4   지역별  대전       149            918.0
# 5   지역별  충북       166            932.0
# 6   지역별  충남       311           1778.0
# 7   지역별  세종        38            223.0
# 8   지역별  광주       159           1354.0
# 9   지역별  전북       176           1011.0
# 10  지역별  전남       174           1361.0
# 11  지역별  대구       214           1186.0
# 12  지역별  경북       280           3491.0
# 13  지역별  부산       376           4203.0
# 14  지역별  울산       167            980.0
# 15  지역별  경남       429           2461.0
# 16  지역별  제주       160           1102.0

# %%
unique_values = df_subset['구분2'].unique()

# Display the unique values as an array
print(unique_values)
# Out:
# ['서울' '인천' '경기' '강원' '대전' '충북' '충남' '세종' '광주' '전북' '전남' '대구' '경북' '부산'
#  '울산' '경남' '제주']

# %% [markdown]
# # **위의 데이터를 가지고 5개의 도로 분류하여 (강원도, 경기도, 충청도, 전라도, 경상도)중에서 체납세액이 높은 것을 시각화하는데 어려움이 있다.**
